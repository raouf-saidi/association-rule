# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import squarify
import seaborn as sns

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
df=pd.DataFrame(dataset
                    )

# %%
dataset
# Out:
#             0         1         2      3      4      5     6
# 0       Skirt  Sneakers     Scarf  Pants    Hat   None  None
# 1  Sunglasses     Skirt  Sneakers  Pants    Hat   None  None
# 2       Dress   Sandals     Scarf  Pants  Heels   None  None
# 3       Dress  Necklace  Earrings  Scarf    Hat  Heels   Hat
# 4    Earrings     Skirt     Skirt  Scarf  Shirt  Pants  None

# %%
plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
pd.DataFrame(dataset[0]).value_counts().plot.bar(color = color)
plt.title('frequency of most popular items', fontsize = 20)
plt.xticks(rotation = 90 )
plt.grid()
plt.show()

# %%
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12212/1480744685.py in <module>
#       1 from mlxtend.frequent_patterns import association_rules
#       2 from mlxtend.frequent_patterns import apriori
# ----> 3 frequent_itemsets=apriori(dataset, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
#       4 frequent_itemsets
#       5 association_rules(frequent_itemsets,metric="confidence",min_threshold=0.3)
#
# ...

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement frequent_patterns (from versions: none)
# ERROR: No matching distribution found for frequent_patterns

# %%
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
datasetaset=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
dataset=pd.DataFrame(te_ary, columns=te.columns_)

# %%
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import apriori
frequent_itemsets=apriori(dataset, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.3)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 1     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 2     (Skirt)     (Pants)                 0.6                 0.8      0.6
# 3     (Pants)     (Skirt)                 0.8                 0.6      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        1.00  1.2500      0.12         inf
# 3        0.75  1.2500      0.12         1.6

# %%
market=pd.read_csv('C:\\Users\\HP\\Documents\\dataset\\Market_Basket_Optimisation.csv',header=None)

# %%
plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
market[0].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular items', fontsize = 20)
plt.xticks(rotation = 90 )
plt.grid()
plt.show()

# %%
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12212/1756769359.py in <module>
# ----> 1 apriori(market, min_support = 0.01, use_colnames = True)
#
# ~\anaconda3\lib\site-packages\mlxtend\frequent_patterns\apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     239         )
#     240
# --> 241     fpc.valid_input_check(df)
#     242
#     243     if hasattr(df, "sparse"):
#
# ~\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py in valid_input_check(df)
# ...

# %%
trans = []
for i in range(0, 7501):
    trans.append([str(market.values[i,j]) for j in range(0, 20)])

# conveting it into an numpy array
trans = np.array(trans)

# checking the shape of the array
print(trans.shape)

trans
# Out:
# (7501, 20)
# array([['shrimp', 'almonds', 'avocado', ..., 'frozen smoothie',
#         'spinach', 'olive oil'],
#        ['burgers', 'meatballs', 'eggs', ..., 'nan', 'nan', 'nan'],
#        ['chutney', 'nan', 'nan', ..., 'nan', 'nan', 'nan'],
#        ...,
#        ['chicken', 'nan', 'nan', ..., 'nan', 'nan', 'nan'],
#        ['escalope', 'green tea', 'nan', ..., 'nan', 'nan', 'nan'],
#        ['eggs', 'frozen smoothie', 'yogurt cake', ..., 'nan', 'nan',
#         'nan']], dtype='<U20')

# %%
te = TransactionEncoder()
data = te.fit_transform(trans)
data = pd.DataFrame(data, columns = te.columns_)

# %%
frequent_itemsets = apriori(data, min_support = 0.05, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#      support                         itemsets  length
# 0   0.087188                        (burgers)       1
# 1   0.081056                           (cake)       1
# 2   0.059992                        (chicken)       1
# 3   0.163845                      (chocolate)       1
# 4   0.080389                        (cookies)       1
# 5   0.051060                    (cooking oil)       1
# 6   0.179709                           (eggs)       1
# 7   0.079323                       (escalope)       1
# 8   0.170911                   (french fries)       1
# 9   0.063325                (frozen smoothie)       1
# 10  0.095321              (frozen vegetables)       1
# 11  0.052393                  (grated cheese)       1
# 12  0.132116                      (green tea)       1
# 13  0.098254                    (ground beef)       1
# 14  0.076523                 (low fat yogurt)       1
# 15  0.129583                           (milk)       1
# ...

# %%
apriori(data, min_support = 0.01, use_colnames = True)
# Out:
#       support                                      itemsets
# 0    0.020397                                     (almonds)
# 1    0.033329                                     (avocado)
# 2    0.010799                              (barbecue sauce)
# 3    0.014265                                   (black tea)
# 4    0.011465                                  (body spray)
# ..        ...                                           ...
# 510  0.011065       (milk, mineral water, nan, ground beef)
# 511  0.017064  (spaghetti, mineral water, nan, ground beef)
# 512  0.015731         (spaghetti, mineral water, milk, nan)
# 513  0.010265    (olive oil, mineral water, spaghetti, nan)
# 514  0.011465     (spaghetti, mineral water, nan, pancakes)
#
# [515 rows x 2 columns]

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'spaghetti', 'mineral water'} ]
# Out:
#      support                    itemsets  length
# 45  0.059725  (spaghetti, mineral water)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == { 'barbecue sauce'} ]
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length]
# Index: []
